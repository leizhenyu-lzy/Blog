# %% [markdown]
# # Objaverse-XL API Tutorial
#
# Objaverse-XL is a Universe of 10M+ 3D Objects.
#
# It is hosted on 🤗[Hugging Face](https://huggingface.co/datasets/allenai/objaverse-xl) and includes a [Python API on GitHub](https://github.com/allenai/objaverse-xl). This notebook provides a tutorial on downloading objects and annotations!
#
# We'll get started by downloading the `objaverse` package from PyPi, which will allow us to easily download subsets of the dataset:

# %%
# %pip install objaverse
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: objaverse in /home/lzy/Projects/Objaverse/objaverse-xl (0.1.7)
# Requirement already satisfied: fsspec>=2022.11.0 in /home/lzy/.local/lib/python3.10/site-packages (from objaverse) (2024.10.0)
# Requirement already satisfied: gputil==1.4.0 in /home/lzy/.local/lib/python3.10/site-packages (from objaverse) (1.4.0)
# Requirement already satisfied: loguru in /home/lzy/.local/lib/python3.10/site-packages (from objaverse) (0.7.2)
# Requirement already satisfied: pandas in /home/lzy/.local/lib/python3.10/site-packages (from objaverse) (2.2.3)
# Requirement already satisfied: pyarrow in /home/lzy/.local/lib/python3.10/site-packages (from objaverse) (18.1.0)
# Requirement already satisfied: requests in /home/lzy/.local/lib/python3.10/site-packages (from objaverse) (2.32.0)
# Requirement already satisfied: tqdm in /home/lzy/.local/lib/python3.10/site-packages (from objaverse) (4.67.0)
# Requirement already satisfied: numpy>=1.22.4 in /home/lzy/.local/lib/python3.10/site-packages (from pandas->objaverse) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lzy/.local/lib/python3.10/site-packages (from pandas->objaverse) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->objaverse) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/lzy/.local/lib/python3.10/site-packages (from pandas->objaverse) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lzy/.local/lib/python3.10/site-packages (from requests->objaverse) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->objaverse) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->objaverse) (2020.6.20)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->objaverse) (1.26.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->objaverse) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import objaverse
print(objaverse.__version__)
# Out:
# <REPLACE_WITH_VERSION>

# %% [markdown]
# The Objaverse-XL API is in the `xl` submodule. Here we'll import it as use the shorthand `oxl` to refer to it:

# %%
import objaverse.xl as oxl

# %% [markdown]
# ## Annotations
#
# The objects that appear in the dataset can be obtained with the `get_annotations` function:
#
# ```python
# oxl.get_annotations(
#     download_dir: str = "~/.objaverse",
# ) -> pd.DataFrame
# ```
#
# The function takes in a parameter for `download_dir: str = "~/.objaverse"`, which is the directory to cache the downloaded annotations.
#
# After the annotations are downloaded for the first time, they do not need to be downloaded again, as they are cached.
#
# For example:

# %%
annotations = oxl.get_annotations(
    download_dir="~/.objaverse" # default download directory
)
annotations
# Out:
# 2024-12-03 14:22:15.274 | INFO     | objaverse.xl.github:_get_annotations:65 - Downloading https://huggingface.co/datasets/allenai/objaverse-xl/resolve/main/github/github.parquet to ~/.objaverse/github/github.parquet
# 2024-12-03 14:23:44.684 | INFO     | objaverse.xl.smithsonian:get_annotations:47 - Downloading https://huggingface.co/datasets/allenai/objaverse-xl/resolve/main/smithsonian/smithsonian.parquet to ~/.objaverse/smithsonian/smithsonian.parquet
# 2024-12-03 14:23:45.057 | INFO     | objaverse.xl.sketchfab:_get_annotations:52 - Downloading https://huggingface.co/datasets/allenai/objaverse-xl/resolve/main/sketchfab/sketchfab.parquet to ~/.objaverse/sketchfab/sketchfab.parquet
#                                             fileIdentifier     source  \
# 0        https://github.com/GameGC/Testovoe-SPB-Git/blo...     github
# 1        https://github.com/9-zzz/RitualRex-GGJ2016/blo...     github
# 2        https://github.com/mattoverby/mesh-data/blob/2...     github
# 3        https://github.com/0010cha/data_origami/blob/0...     github
# 4        https://github.com/Xrvitd/Point2Skeleton_withC...     github
# ...                                                    ...        ...
# 6034794  https://sketchfab.com/3d-models/cc2c9ac5149b40...  sketchfab
# 6034795  https://sketchfab.com/3d-models/48ad63b00c4448...  sketchfab
# 6034796  https://sketchfab.com/3d-models/3f61c303139f4d...  sketchfab
# 6034797  https://sketchfab.com/3d-models/bc79ba06d75740...  sketchfab
# 6034798  https://sketchfab.com/3d-models/4d03e14ded2a4d...  sketchfab
#
#                                 license fileType  \
# 0                                  None      obj
# 1                                  None    blend
# 2                           MIT License      obj
# 3                           MIT License      ply
# 4                           MIT License      ply
# ...                                 ...      ...
# 6034794  Creative Commons - Attribution      glb
# 6034795  Creative Commons - Attribution      glb
# 6034796  Creative Commons - Attribution      glb
# 6034797  Creative Commons - Attribution      glb
# 6034798  Creative Commons - Attribution      glb
#
#                                                     sha256 metadata
# 0        fca3990d6d91e110cb920aa3da1a84e54b4a00cde7ad1e...       {}
# 1        09dc2689b8d0510885e19a7b525ee44709849d2601add8...       {}
# 2        f9d17190b54b548c6a3e6feebe7b2951a9b8060c507874...       {}
# 3        f25184898312af8ed5e77cfe675d2251c9893ac5ccc3a1...       {}
# 4        d721e6b1b97a83d1f6700045efcb478a1db4686b0571f6...       {}
# ...                                                    ...      ...
# 6034794  76cc3e0343be2452fb7a1d8f6eb295f9067e859f353bb8...       {}
# 6034795  15524e631cecaf3537bbbd9756a94ffa78b275ce77e683...       {}
# 6034796  4b4a2c0e5f4bd89b15c9551c7c34c0083774ead2fb6354...       {}
# 6034797  9e71bc509985344446e075bac884cd1a76c24b09f82217...       {}
# 6034798  a4e94c097ffbad25e18f95a94ea5ed0daa102847e329c8...       {}
#
# [6034799 rows x 6 columns]

# %% [markdown]
# > Note: Some objects are still under review for being publicly released.
#
# Here, `annotations` is a pandas DataFrame. These annotations are meant to provide a minimal amount of information about the objects that are standarized across each source and allow it to be downloaded. Each object is a row, and has attributes for:
# - `fileIdentifier` - A unique identifier of the 3D object. Typically the `URL` that links back to the object.
# - `source` - The website where the 3D object comes from.
# - `license` - The license that the original object was distributed under.
# - `fileType` - The 3D file type of the object (e.g., `fbx`, `obj`, `glb`).
# - `sha256` - The cryptographic hash of the contents of the object (used for deduplication and to check if the object has not been modified since the dataset was originally released).
# - `metadata` - Additional metadata of the object that might be site specific (e.g., the file name). To keep the `annotations` DataFrame lightweight, more detailed annotations may be available as standalone functions (e.g., `objaverse.load_lvis_annotations()`). See the Objaverse 1.0 documentation for more specific annotations.
#
# Since the annotations is a pandas DataFrame object, we can do standard operations on it, such as getting the value counts of different attributes:

# %%
annotations["source"].value_counts()
# Out:
# source
# github         5236361
# sketchfab       796031
# smithsonian       2407
# Name: count, dtype: int64

# %%
annotations["fileType"].value_counts()
# Out:
# fileType
# obj      1620083
# fbx      1509719
# glb       985124
# ply       839343
# stl       584870
# blend     238201
# gltf      127287
# dae       123438
# usdz        5681
# abc         1053
# Name: count, dtype: int64

# %% [markdown]
# And randomly sample objects:

# %%
annotations.sample(5)
# Out:
#                                             fileIdentifier     source  \
# 1856580  https://github.com/Maxim-Durand/generativeArt/...     github
# 5595826  https://sketchfab.com/3d-models/f04af5479b5241...  sketchfab
# 3327390  https://github.com/cake2000/tgameshare/blob/34...     github
# 4316358  https://github.com/sarettak/3DCityReconstructi...     github
# 4495117  https://github.com/Canonelis/ttsjiggys/blob/00...     github
#
#                                 license fileType  \
# 1856580                            None      obj
# 5595826  Creative Commons - Attribution      glb
# 3327390                            None      glb
# 4316358                     MIT License      ply
# 4495117                            None      obj
#
#                                                     sha256 metadata
# 1856580  e0ceb77ea0160889a99fabb84076160d35625947916700...       {}
# 5595826  c5162db1de6f6563237dea479a265dfbdc5f485592ddc0...       {}
# 3327390  32af16df09dce957c5c79b0fe45f4f6667a7a9460f83d9...       {}
# 4316358  c2969f9c875b29d9ffc5aef029e9234484faa59968a63a...       {}
# 4495117  7e5da43cb1da78acfa61d0bd256319fbe1df3f4db6362c...       {}

# %% [markdown]
# ## Alignment Fine-tuning Annotations
#
# For training Zero123-XL, we first started by training on the entire dataset, and then performed fine-tuning on a smaller, more high-quality 3D dataset. To load in the dataset that was used for fine-tuning, we can run:

# %%
alignment_annotations = oxl.get_alignment_annotations(
    download_dir="~/.objaverse" # default download directory
)
alignment_annotations
# Out:
# 2024-12-03 14:23:53.835 | INFO     | objaverse.xl.github:_get_annotations:65 - Downloading https://huggingface.co/datasets/allenai/objaverse-xl/resolve/main/github/alignment.parquet to ~/.objaverse/github/alignment.parquet
# 2024-12-03 14:24:06.175 | INFO     | objaverse.xl.sketchfab:_get_annotations:52 - Downloading https://huggingface.co/datasets/allenai/objaverse-xl/resolve/main/sketchfab/alignment.parquet to ~/.objaverse/sketchfab/alignment.parquet
#                                             fileIdentifier     source  \
# 0        https://github.com/iitiansd/AR-Institute-GEO-L...     github
# 1        https://github.com/Phipson/SyntheticShapeShift...     github
# 2        https://github.com/megat69/ProjectRebirth/blob...     github
# 3        https://github.com/cellphone-cmyk/miHoYoTest/b...     github
# 4        https://github.com/dededec/TFM_Esada/blob/5d82...     github
# ...                                                    ...        ...
# 1083981  https://sketchfab.com/3d-models/c0a4a8dd621744...  sketchfab
# 1083982  https://sketchfab.com/3d-models/4225f6c6cc1344...  sketchfab
# 1083983  https://sketchfab.com/3d-models/eac150307b6f45...  sketchfab
# 1083984  https://sketchfab.com/3d-models/48ad63b00c4448...  sketchfab
# 1083985  https://sketchfab.com/3d-models/3f61c303139f4d...  sketchfab
#
#                                               license fileType  \
# 0                                                None     gltf
# 1                                                None      fbx
# 2                                         MIT License      obj
# 3                                                None      fbx
# 4                                                None      glb
# ...                                               ...      ...
# 1083981                Creative Commons - Attribution      glb
# 1083982  Creative Commons - Attribution - Share Alike      glb
# 1083983                Creative Commons - Attribution      glb
# 1083984                Creative Commons - Attribution      glb
# 1083985                Creative Commons - Attribution      glb
#
#                                                     sha256 metadata
# 0        aac5c4f71125f9183b8bbf359691489b7a9ed696b493a8...       {}
# 1        4be8a7f1b5b50ffa78c757e33ce0eb7e6a7f519f6018c6...       {}
# 2        38c6785d5cc593e6012d4dcdbb5586736501cf0c06edd6...       {}
# 3        a7a1957a9bdf9ee223302fb53e7dabf34f02ead84ae1c7...       {}
# 4        0859233e43aa22f720b0bcc6f081708c1c391bcb15a44d...       {}
# ...                                                    ...      ...
# 1083981  20e23e224f4f4cb1243563d9daddfc21a7269c2aff9bfe...       {}
# 1083982  eb964e3c1a945b129fb396065858cb0f8cf9889dcbccae...       {}
# 1083983  becba4ce17c75352909e70c71bd48b7c5cd55e7469cbdd...       {}
# 1083984  15524e631cecaf3537bbbd9756a94ffa78b275ce77e683...       {}
# 1083985  4b4a2c0e5f4bd89b15c9551c7c34c0083774ead2fb6354...       {}
#
# [1083986 rows x 6 columns]

# %% [markdown]
# ## Download Objects
#
# Downloading objects can be done through the `download_objects` function:
#
# ```python
# oxl.download_objects(
#     # Base parameters:
#     objects: pd.DataFrame,
#     download_dir: str = "~/.objaverse",
#     processes: Optional[int] = None,  # None => multiprocessing.cpu_count()
#
#     # optional callback functions:
#     handle_found_object: Optional[Callable] = None,
#     handle_modified_object: Optional[Callable] = None,
#     handle_missing_object: Optional[Callable] = None,
#
#     # GitHub specific:
#     save_repo_format: Optional[Literal["zip", "tar", "tar.gz", "files"]] = None,
#     handle_new_object: Optional[Callable] = None,
# )
# ```
#
# The function supports several different types of parameters, which we've broken down into base parameters, callback functions, and GitHub specific parameters.
#
# **Base parameters.**
#
# - `objects: pd.DataFrame` a pandas DataFrame the objects to download. Must have columns for the object "fileIdentifier", "source", and "sha256". Use the `oxl.get_annotations` function to get all objects as a DataFrame.
# - `download_dir: Optional[str] = "~/.objaverse"` specifies where to download the objects.
#
#     Thanks to fsspec, we support writing files to many file systems. To use it, simply use the prefix of your filesystem before the path. For example hdfs://, s3://, http://, gcs://, or ssh://. Some of these file systems require installing an additional package (for example s3fs for s3, gcsfs for gcs, fsspec/sshfs for ssh). Start [here](https://github.com/rom1504/img2dataset#file-system-support) for more details on fsspec.
#
#     If None, the objects will be deleted after they are downloaded. Defaults to "~/.objaverse".
# - `processes: Optional[int] = None` number of processes to use when downloading the objects. If None, it will use the number of CPUs on the machine (which comes from `multiprocessing.cpu_count()`). Defaults to None.
#
# **Callback function parameters.**
# The function also supports several callback functions, which are called right after an object is locally downloaded. Common use cases for these callback functions may include downloading objects on the fly and processing them with Blender, rendering them, then discarding them. The specific callback functions include:
#
# - `handle_found_object: Optional[Callable] = None` is called when an object is successfully found and downloaded. Here, the object has the same sha256 as the one that was downloaded with Objaverse-XL. If None, the object will be downloaded, but nothing will be done with it.
#
#   Parameters for the function must include:
#     - `local_path: str` Local path to the downloaded 3D object.
#     - `file_identifier: str` File identifier of the 3D object.
#     - `sha256: str` sha256 of the contents of the 3D object.
#     - `metadata: Dict[Hashable, Any]` Metadata about the 3D object, such as the GitHub organization and repo name.
#
#   The return of the function is not used.
#
# - `handle_modified_object: Optional[Callable] = None` is called when a modified object is found and downloaded. Here, the object is successfully downloaded, but it has a different sha256 than the one that was downloaded with Objaverse-XL. This is not expected to happen very often, because the same commit hash is used for each repo. If None, the object will be downloaded, but nothing will be done with it.
#
#     Parameters for the function must include:
#     - `local_path: str` Local path to the downloaded 3D object.
#     - `file_identifier: str` File identifier of the 3D object.
#     - `new_sha256: str` sha256 of the contents of the newly downloaded 3D object.
#     - `old_sha256: str` Provided sha256 representing the contents of the 3D object as it was originally intended to be downloaded (coming from the `objects` argument).
#     - `metadata: Dict[Hashable, Any]` Metadata about the 3D object, such as the GitHub organization and repo name.
#
#   The return of the function is not used.
#
# - `handle_missing_object: Optional[Callable] = None` is called when a specified object cannot be found. Here, it is likely that the object was deleted or the repository was deleted or renamed. If None, nothing will be done with the missing object.
#
#     Parameters for the function must include:
#     - `file_identifier: str` File identifier of the 3D object.
#     - `sha256: str` Provided sha256 representing the contents of the 3D object as it was originally intended to be downloaded (coming from the `objects` argument).
#     - `metadata: Dict[Hashable, Any]` Metadata about the 3D object, which is particular to the source.
#
#   The return of the function is not used.
#
# **GitHub specific parameters.** There are several parameters that are only used when downloading objects from GitHub. These parameters can still be passed in when downloading objects from other sources, but they will not be used. These parameters include:
#
# - `save_repo_format: Optional[Literal["zip", "tar", "tar.gz", "files"]] = None` specifies the format to save the GitHub repository. Unlike other sources, GitHub objects are not standalone 3D files, and may link to other assets, such as textures. If None, the repository will not be saved. If "files" is specified, each file will be saved individually in a standard folder structure. Otherwise, the repository can be saved as a "zip", "tar", or "tar.gz" file. Defaults to None.
#
# - `handle_new_object: Optional[Callable]` is called when a new object is found. Here, the object is not used in Objaverse-XL, but is still downloaded as part of the repository. Note that the object may have not been used because it does not successfully import into Blender. If None, the object will be downloaded, but nothing will be done with it.
#
#     Parameters for the function must include:
#     - `local_path: str` Local path to the downloaded 3D object.
#     - `file_identifier: str` GitHub URL of the 3D object.
#     - `sha256: str` sha256 of the contents of the 3D object.
#     - `metadata: Dict[str, Any]` Metadata about the 3D object, such as the GitHub organization and repo names.
#
#   The return of the function is not used.
#
#
# The following is a minimal example of using `oxl.download_objects`:

# %%
# sample a single object from each source
sampled_df = annotations.groupby('source').apply(lambda x: x.sample(1)).reset_index(drop=True)
sampled_df
# Out:
# /tmp/ipykernel_1629462/110970031.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = annotations.groupby('source').apply(lambda x: x.sample(1)).reset_index(drop=True)
#                                       fileIdentifier       source  \
# 0  https://github.com/gamesketches/MFAThesisJams/...       github
# 1  https://sketchfab.com/3d-models/1da88d8556d04c...    sketchfab
# 2  https://3d-api.si.edu/content/document/3d_pack...  smithsonian
#
#                                 license fileType  \
# 0                                  None      fbx
# 1        Creative Commons - Attribution      glb
# 2  Creative Commons Zero v1.0 Universal      glb
#
#                                               sha256  \
# 0  62e79c71c25f0b01363a9804f2f4a2606c6a0f65f76130...
# 1  4f95b3e0907ac4711f2f3a9c75063ca40a082a6543a896...
# 2  cdedc7daa7862138d8b43ba0cef5c595bc3dd1a65c77c0...
#
#                                             metadata
# 0                                                 {}
# 1                                                 {}
# 2  {"title": "Theropithecus gelada gelada: Mandib...

# %%
print(sampled_df['fileIdentifier'][0])
# Out:
# https://github.com/gamesketches/MFAThesisJams/blob/bc0bf58708f131b797245f30c94dedff870f7b92/Floriography/Assets/3D Models/tulipflippednormals.fbx

# %%
oxl.download_objects(objects=sampled_df)
# Out:
# 2024-12-03 14:50:09.484 | INFO     | objaverse.xl.smithsonian:download_objects:312 - Found 0 Smithsonian Objects already downloaded
# 2024-12-03 14:50:09.486 | INFO     | objaverse.xl.smithsonian:download_objects:315 - Downloading 1 Smithsonian Objects with 32 processes
# Downloading Smithsonian Objects: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# 2024-12-03 14:50:14.488 | INFO     | objaverse.xl.sketchfab:download_objects:508 - Found 0 objects already downloaded
# 2024-12-03 14:50:14.489 | INFO     | objaverse.xl.sketchfab:download_objects:529 - Downloading 1 new objects across 32 processes
# 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# 2024-12-03 14:50:17.766 | INFO     | objaverse.xl.github:download_objects:602 - Provided 1 repoIds with 1 objects to process.
# 2024-12-03 14:50:17.767 | INFO     | objaverse.xl.github:download_objects:614 - Found 1 repoIds not yet downloaded. Downloading now...
# Grouping objects by repository: 100%|██████████| 1/1 [00:00<00:00, 664.60it/s]
# Handling 3D object files: 100%|██████████| 7/7 [00:00<00:00, 2314.74it/s]
# Downloading repositories: 100%|██████████| 1/1 [00:01<00:00,  1.55s/it]
# {'https://3d-api.si.edu/content/document/3d_package:1f947dd0-808a-48c5-a489-da7b1da2b38e/USNM319992_mandible_-200-150k-2048-medium.glb': '/home/lzy/.objaverse/smithsonian/objects/fd0cee67-0091-5346-af0e-57a3a906311b.glb',
#  'https://sketchfab.com/3d-models/1da88d8556d04ce5adf8dbfba19f3207': '/home/lzy/.objaverse/hf-objaverse-v1/glbs/000-140/1da88d8556d04ce5adf8dbfba19f3207.glb'}

# %%
github_sampled_df = sampled_df.iloc[:1]
oxl.download_objects(objects=github_sampled_df, save_repo_format="files")
# Out:
# 2024-12-03 14:51:54.596 | INFO     | objaverse.xl.github:download_objects:602 - Provided 1 repoIds with 1 objects to process.
# 2024-12-03 14:51:54.597 | INFO     | objaverse.xl.github:download_objects:614 - Found 1 repoIds not yet downloaded. Downloading now...
# Grouping objects by repository: 100%|██████████| 1/1 [00:00<00:00, 514.13it/s]
# Handling 3D object files: 100%|██████████| 7/7 [00:00<00:00, 2700.53it/s]
# 2024-12-03 14:52:02.854 | DEBUG    | objaverse.xl.github:_process_repo:328 - Saving gamesketches/MFAThesisJams as files
# Downloading repositories: 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# {'https://github.com/gamesketches/MFAThesisJams/blob/bc0bf58708f131b797245f30c94dedff870f7b92/Floriography/Assets/3D Models/tulipflippednormals.fbx': '/home/lzy/.objaverse/github/repos/gamesketches/MFAThesisJams/Floriography/Assets/3D Models/tulipflippednormals.fbx'}

# %% [markdown]
# Great! As we can see, the objects were successfully downloaded. Note that the GitHub objects were not saved, since `save_repo_format` defaults to None, so they are not included in the output return.
#
# Next, we'll show an example using callback functions, which work well when downloading and processing GitHub objects.
#
# We'll start by removing the `~/.objaverse` directory to clear the cache of the objects that we just downloaded, so they'll be downloaded again from scratch. Otherwise, the objects will be cached and not downloaded for a 2nd time:

# %%
import shutil
import os

shutil.rmtree(os.path.expanduser("~/.objaverse"), ignore_errors=True)

# %% [markdown]
# And we'll define our `handle_found_object` function, which is called after an object is downloaded and has a sha256 that matches the one that we supplied:

# %%
from typing import Any, Dict, Hashable

def handle_found_object(
    local_path: str,
    file_identifier: str,
    sha256: str,
    metadata: Dict[Hashable, Any]
) -> None:
    print("\n\n\n---HANDLE_FOUND_OBJECT CALLED---\n",
          f"  {local_path=}\n  {file_identifier=}\n  {sha256=}\n  {metadata=}\n\n\n")

# %% [markdown]
# Now, after running the same function with the `handle_found_object` callback, we have:

# %%
oxl.download_objects(
    objects=sampled_df,
    handle_found_object=handle_found_object
)
# Out:
# 2024-12-03 14:16:35.117 | INFO     | objaverse.xl.smithsonian:download_objects:312 - Found 0 Smithsonian Objects already downloaded
# 2024-12-03 14:16:35.119 | INFO     | objaverse.xl.smithsonian:download_objects:315 - Downloading 1 Smithsonian Objects with 32 processes
# Downloading Smithsonian Objects:   0%|          | 0/1 [00:00<?, ?it/s]
# ---HANDLE_FOUND_OBJECT CALLED---
#    local_path='/tmp/tmpq92og_86/31421480-4f0c-550f-afd1-a4b791dc59a2.glb'
#   file_identifier='https://3d-api.si.edu/content/document/3d_package:eb2cdb65-0c0d-43ee-b0e4-a735d0795d07/USNM176228_talus_right_-300-150k-2048-medium.glb'
#   sha256='e078021dd987a89360b6d4052331bb09bf441aac878d79dea2aa9f56104c8ecc'
#   metadata={}
# Downloading Smithsonian Objects: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# 2024-12-03 14:16:40.236 | INFO     | objaverse.xl.sketchfab:download_objects:508 - Found 0 objects already downloaded
# 2024-12-03 14:16:40.236 | INFO     | objaverse.xl.sketchfab:download_objects:529 - Downloading 1 new objects across 32 processes
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---HANDLE_FOUND_OBJECT CALLED---
#    local_path='/tmp/tmp45o5mbmq/glbs/000-060/c5db69692262401c8fcce0567135894e.glb'
#   file_identifier='https://sketchfab.com/3d-models/c5db69692262401c8fcce0567135894e'
#   sha256='6cb59e75b325c47e0858ace632e83ade27d05a0eadf9828750a105359ca76a7f'
#   metadata={}
# 100%|██████████| 1/1 [00:08<00:00,  8.71s/it]
# 2024-12-03 14:16:50.588 | INFO     | objaverse.xl.github:download_objects:602 - Provided 1 repoIds with 1 objects to process.
# 2024-12-03 14:16:50.589 | INFO     | objaverse.xl.github:download_objects:614 - Found 1 repoIds not yet downloaded. Downloading now...
# Grouping objects by repository: 100%|██████████| 1/1 [00:00<00:00, 372.36it/s]
# Handling 3D object files:  28%|██▊       | 445/1584 [00:00<00:00, 2250.31it/s]
# ---HANDLE_FOUND_OBJECT CALLED---
#    local_path='/tmp/tmpkhp7uigx/SCO_planning/robots/ABB/IRB1200_7_70b/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/ABB/IRB1200_7_70b/link2.stl'
#   sha256='92ff108114c70f65c8db06f765577362ab2c9568161b84a64f6d0e9df67ca831'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
# Handling 3D object files: 100%|██████████| 1584/1584 [00:00<00:00, 2778.94it/s]
# Downloading repositories: 100%|██████████| 1/1 [00:25<00:00, 25.88s/it]
# {'https://3d-api.si.edu/content/document/3d_package:eb2cdb65-0c0d-43ee-b0e4-a735d0795d07/USNM176228_talus_right_-300-150k-2048-medium.glb': '/home/lzy/.objaverse/smithsonian/objects/31421480-4f0c-550f-afd1-a4b791dc59a2.glb',
#  'https://sketchfab.com/3d-models/c5db69692262401c8fcce0567135894e': '/home/lzy/.objaverse/hf-objaverse-v1/glbs/000-060/c5db69692262401c8fcce0567135894e.glb'}

# %% [markdown]
# Notice that our custom `handle_found_object` function is called right after each object is locally downloaded!
#
# Next, for the `handle_modified_object` callback, let's change the sha256 of one of the objects and then try to download it:

# %%
modified_df = sampled_df.copy()
modified_df.iloc[0]["sha256"] = "modified-sha256"
modified_df
# Out:
# /tmp/ipykernel_1629462/1129776298.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   modified_df.iloc[0]["sha256"] = "modified-sha256"
#                                       fileIdentifier       source  \
# 0  https://github.com/jcarballeira/SCO_planning/b...       github
# 1  https://sketchfab.com/3d-models/c5db6969226240...    sketchfab
# 2  https://3d-api.si.edu/content/document/3d_pack...  smithsonian
#
#                                 license fileType  \
# 0                                  None      stl
# 1        Creative Commons - Attribution      glb
# 2  Creative Commons Zero v1.0 Universal      glb
#
#                                               sha256  \
# 0                                    modified-sha256
# 1  6cb59e75b325c47e0858ace632e83ade27d05a0eadf982...
# 2  e078021dd987a89360b6d4052331bb09bf441aac878d79...
#
#                                             metadata
# 0                                                 {}
# 1                                                 {}
# 2  {"title": "Pan troglodytes troglodytes: Talus ...

# %%
def handle_modified_object(
    local_path: str,
    file_identifier: str,
    new_sha256: str,
    old_sha256: str,
    metadata: Dict[Hashable, Any],
) -> None:
    print("\n\n\n---HANDLE_MODIFIED_OBJECT CALLED---\n",
          f"  {local_path=}\n  {file_identifier=}\n  {old_sha256=}\n  {new_sha256}\n  {metadata=}\n\n\n")

# %%
# remove previously downloaded objects
shutil.rmtree(os.path.expanduser("~/.objaverse"), ignore_errors=True)

# redownload
oxl.download_objects(
    objects=modified_df,
    handle_found_object=handle_found_object,
    handle_modified_object=handle_modified_object  # <---------------
)
# Out:
# 2024-12-03 14:17:18.490 | INFO     | objaverse.xl.smithsonian:download_objects:312 - Found 0 Smithsonian Objects already downloaded
# 2024-12-03 14:17:18.491 | INFO     | objaverse.xl.smithsonian:download_objects:315 - Downloading 1 Smithsonian Objects with 32 processes
# Downloading Smithsonian Objects:   0%|          | 0/1 [00:00<?, ?it/s]
# ---HANDLE_FOUND_OBJECT CALLED---
#    local_path='/tmp/tmpnbdc7vvy/31421480-4f0c-550f-afd1-a4b791dc59a2.glb'
#   file_identifier='https://3d-api.si.edu/content/document/3d_package:eb2cdb65-0c0d-43ee-b0e4-a735d0795d07/USNM176228_talus_right_-300-150k-2048-medium.glb'
#   sha256='e078021dd987a89360b6d4052331bb09bf441aac878d79dea2aa9f56104c8ecc'
#   metadata={}
# Downloading Smithsonian Objects: 100%|██████████| 1/1 [00:00<00:00,  1.47it/s]
# 2024-12-03 14:17:23.680 | INFO     | objaverse.xl.sketchfab:download_objects:508 - Found 0 objects already downloaded
# 2024-12-03 14:17:23.681 | INFO     | objaverse.xl.sketchfab:download_objects:529 - Downloading 1 new objects across 32 processes
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---HANDLE_FOUND_OBJECT CALLED---
#    local_path='/tmp/tmpjpw3nhhw/glbs/000-060/c5db69692262401c8fcce0567135894e.glb'
#   file_identifier='https://sketchfab.com/3d-models/c5db69692262401c8fcce0567135894e'
#   sha256='6cb59e75b325c47e0858ace632e83ade27d05a0eadf9828750a105359ca76a7f'
#   metadata={}
# 100%|██████████| 1/1 [00:09<00:00,  9.20s/it]
# 2024-12-03 14:17:34.886 | INFO     | objaverse.xl.github:download_objects:602 - Provided 1 repoIds with 1 objects to process.
# 2024-12-03 14:17:34.887 | INFO     | objaverse.xl.github:download_objects:614 - Found 1 repoIds not yet downloaded. Downloading now...
# Grouping objects by repository: 100%|██████████| 1/1 [00:00<00:00, 693.39it/s]
# Handling 3D object files:  42%|████▏     | 673/1584 [00:00<00:00, 2183.14it/s]
# ---HANDLE_MODIFIED_OBJECT CALLED---
#    local_path='/tmp/tmpt2j63qzd/SCO_planning/robots/ABB/IRB1200_7_70b/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/ABB/IRB1200_7_70b/link2.stl'
#   old_sha256='modified-sha256'
#   92ff108114c70f65c8db06f765577362ab2c9568161b84a64f6d0e9df67ca831
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
# Handling 3D object files: 100%|██████████| 1584/1584 [00:00<00:00, 2617.40it/s]
# Downloading repositories: 100%|██████████| 1/1 [00:23<00:00, 23.01s/it]
# {'https://3d-api.si.edu/content/document/3d_package:eb2cdb65-0c0d-43ee-b0e4-a735d0795d07/USNM176228_talus_right_-300-150k-2048-medium.glb': '/home/lzy/.objaverse/smithsonian/objects/31421480-4f0c-550f-afd1-a4b791dc59a2.glb',
#  'https://sketchfab.com/3d-models/c5db69692262401c8fcce0567135894e': '/home/lzy/.objaverse/hf-objaverse-v1/glbs/000-060/c5db69692262401c8fcce0567135894e.glb'}

# %% [markdown]
# Notice that `handle_found_object` was called 3 times and `handle_modified_object` was called once, for the object that has its sha256 modified!
#
# We'll do something similar to experiment with `handle_missing_object`, where we'll add modify the path of one of the objects to something that doesn't exist:

# %%
missing_df = sampled_df.copy()
missing_df.iloc[1]["fileIdentifier"] += "-i-do-not-exist"

print(missing_df.iloc[1]["fileIdentifier"])
missing_df
# Out:
# https://sketchfab.com/3d-models/c5db69692262401c8fcce0567135894e-i-do-not-exist
# /tmp/ipykernel_1629462/3847346955.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   missing_df.iloc[1]["fileIdentifier"] += "-i-do-not-exist"
#                                       fileIdentifier       source  \
# 0  https://github.com/jcarballeira/SCO_planning/b...       github
# 1  https://sketchfab.com/3d-models/c5db6969226240...    sketchfab
# 2  https://3d-api.si.edu/content/document/3d_pack...  smithsonian
#
#                                 license fileType  \
# 0                                  None      stl
# 1        Creative Commons - Attribution      glb
# 2  Creative Commons Zero v1.0 Universal      glb
#
#                                               sha256  \
# 0  92ff108114c70f65c8db06f765577362ab2c9568161b84...
# 1  6cb59e75b325c47e0858ace632e83ade27d05a0eadf982...
# 2  e078021dd987a89360b6d4052331bb09bf441aac878d79...
#
#                                             metadata
# 0                                                 {}
# 1                                                 {}
# 2  {"title": "Pan troglodytes troglodytes: Talus ...

# %%
print(missing_df["fileIdentifier"][1])
# Out:
# https://sketchfab.com/3d-models/c5db69692262401c8fcce0567135894e-i-do-not-exist

# %%
def handle_missing_object(
    file_identifier: str,
    sha256: str,
    metadata: Dict[Hashable, Any]
) -> None:
    print("\n\n\n---HANDLE_MISSING_OBJECT CALLED---\n",
          f"  {file_identifier=}\n  {sha256=}\n  {metadata=}\n\n\n")

# %%
# remove previously downloaded objects
shutil.rmtree(os.path.expanduser("~/.objaverse"), ignore_errors=True)

# redownload
oxl.download_objects(
    objects=missing_df,
    handle_found_object=handle_found_object,
    handle_modified_object=handle_modified_object,
    handle_missing_object=handle_missing_object  # <---------------
)
# Out:
# 2024-12-03 14:18:00.504 | INFO     | objaverse.xl.smithsonian:download_objects:312 - Found 0 Smithsonian Objects already downloaded
# 2024-12-03 14:18:00.505 | INFO     | objaverse.xl.smithsonian:download_objects:315 - Downloading 1 Smithsonian Objects with 32 processes
# Downloading Smithsonian Objects:   0%|          | 0/1 [00:00<?, ?it/s]
# ---HANDLE_FOUND_OBJECT CALLED---
#    local_path='/tmp/tmpsrp5rgcz/31421480-4f0c-550f-afd1-a4b791dc59a2.glb'
#   file_identifier='https://3d-api.si.edu/content/document/3d_package:eb2cdb65-0c0d-43ee-b0e4-a735d0795d07/USNM176228_talus_right_-300-150k-2048-medium.glb'
#   sha256='e078021dd987a89360b6d4052331bb09bf441aac878d79dea2aa9f56104c8ecc'
#   metadata={}
# Downloading Smithsonian Objects: 100%|██████████| 1/1 [00:00<00:00,  2.46it/s]
# 2024-12-03 14:18:05.043 | INFO     | objaverse.xl.sketchfab:download_objects:508 - Found 0 objects already downloaded
# 2024-12-03 14:18:05.044 | ERROR    | objaverse.xl.sketchfab:download_objects:517 - Could not find object with uid c5db69692262401c8fcce0567135894e-i-do-not-exist. Skipping it.
# 2024-12-03 14:18:05.045 | INFO     | objaverse.xl.sketchfab:download_objects:529 - Downloading 0 new objects across 32 processes
# 2024-12-03 14:18:05.076 | INFO     | objaverse.xl.github:download_objects:602 - Provided 1 repoIds with 1 objects to process.
# 2024-12-03 14:18:05.077 | INFO     | objaverse.xl.github:download_objects:614 - Found 1 repoIds not yet downloaded. Downloading now...
# ---HANDLE_MISSING_OBJECT CALLED---
#    file_identifier='https://sketchfab.com/3d-models/c5db69692262401c8fcce0567135894e-i-do-not-exist'
#   sha256='6cb59e75b325c47e0858ace632e83ade27d05a0eadf9828750a105359ca76a7f'
#   metadata={}
# Grouping objects by repository: 100%|██████████| 1/1 [00:00<00:00, 420.90it/s]
# Handling 3D object files:  44%|████▍     | 700/1584 [00:00<00:00, 2367.62it/s]
# ---HANDLE_FOUND_OBJECT CALLED---
#    local_path='/tmp/tmpl_oqpxs7/SCO_planning/robots/ABB/IRB1200_7_70b/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/ABB/IRB1200_7_70b/link2.stl'
#   sha256='92ff108114c70f65c8db06f765577362ab2c9568161b84a64f6d0e9df67ca831'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
# Handling 3D object files: 100%|██████████| 1584/1584 [00:00<00:00, 3100.72it/s]
# Downloading repositories: 100%|██████████| 1/1 [00:23<00:00, 23.56s/it]
# {'https://3d-api.si.edu/content/document/3d_package:eb2cdb65-0c0d-43ee-b0e4-a735d0795d07/USNM176228_talus_right_-300-150k-2048-medium.glb': '/home/lzy/.objaverse/smithsonian/objects/31421480-4f0c-550f-afd1-a4b791dc59a2.glb'}

# %% [markdown]
# Great! Notice how we get an error that the object could not be found and that our `handle_missing_object` callback is called!
#
# Finally, we'll also add a callback for `handle_new_object`, which will be called for every object that is in the repository, but not in the objects that we supplied for it to expect to download:

# %%
def handle_new_object(
    local_path: str,
    file_identifier: str,
    sha256: str,
    metadata: Dict[Hashable, Any]
) -> None:
    print("\n\n\n---HANDLE_NEW_OBJECT CALLED---\n",
          f"  {local_path=}\n  {file_identifier=}\n  {sha256=}\n  {metadata=}\n\n\n")

# %%
# remove previously downloaded objects
shutil.rmtree(os.path.expanduser("~/.objaverse"), ignore_errors=True)

# redownload
oxl.download_objects(
    objects=sampled_df,
    handle_found_object=handle_found_object,
    handle_modified_object=handle_modified_object,
    handle_missing_object=handle_missing_object,
    handle_new_object=handle_new_object,  # <---------------
)
# Out:
# 2024-12-03 14:18:31.311 | INFO     | objaverse.xl.smithsonian:download_objects:312 - Found 0 Smithsonian Objects already downloaded
# 2024-12-03 14:18:31.312 | INFO     | objaverse.xl.smithsonian:download_objects:315 - Downloading 1 Smithsonian Objects with 32 processes
# Downloading Smithsonian Objects:   0%|          | 0/1 [00:00<?, ?it/s]
# ---HANDLE_FOUND_OBJECT CALLED---
#    local_path='/tmp/tmpcp_7vj2k/31421480-4f0c-550f-afd1-a4b791dc59a2.glb'
#   file_identifier='https://3d-api.si.edu/content/document/3d_package:eb2cdb65-0c0d-43ee-b0e4-a735d0795d07/USNM176228_talus_right_-300-150k-2048-medium.glb'
#   sha256='e078021dd987a89360b6d4052331bb09bf441aac878d79dea2aa9f56104c8ecc'
#   metadata={}
# Downloading Smithsonian Objects: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# 2024-12-03 14:18:36.475 | INFO     | objaverse.xl.sketchfab:download_objects:508 - Found 0 objects already downloaded
# 2024-12-03 14:18:36.476 | INFO     | objaverse.xl.sketchfab:download_objects:529 - Downloading 1 new objects across 32 processes
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---HANDLE_FOUND_OBJECT CALLED---
#    local_path='/tmp/tmpj2rxvk1g/glbs/000-060/c5db69692262401c8fcce0567135894e.glb'
#   file_identifier='https://sketchfab.com/3d-models/c5db69692262401c8fcce0567135894e'
#   sha256='6cb59e75b325c47e0858ace632e83ade27d05a0eadf9828750a105359ca76a7f'
#   metadata={}
# 100%|██████████| 1/1 [00:09<00:00,  9.25s/it]
# 2024-12-03 14:18:48.099 | INFO     | objaverse.xl.github:download_objects:602 - Provided 1 repoIds with 1 objects to process.
# 2024-12-03 14:18:48.100 | INFO     | objaverse.xl.github:download_objects:614 - Found 1 repoIds not yet downloaded. Downloading now...
# Grouping objects by repository: 100%|██████████| 1/1 [00:00<00:00, 234.38it/s]
# Handling 3D object files:   0%|          | 0/1584 [00:00<?, ?it/s]
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/link5.stl'
#   sha256='479b53721d03e95e983b5d84365e1d2485616199429090587b69ffeea887ce3c'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/link4.stl'
#   sha256='2bac9229dd1194b1038d85ce31c50b2ef6d2c0d72b6517c50f9b1165b82e5593'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/link1.stl'
#   sha256='7c1bb4854155624784d28c3a68ce64597691eff105a706eb8070443de50820b3'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/link2.stl'
#   sha256='a237d4696f6a03c8313d6f67135e855a6256fb353ad6606f577041b63aad3949'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/link6.stl'
#   sha256='d0e5bec2f39f16450583029d5c89fc500871395325ee212206d76fee65be2fe1'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/._link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/._link6.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/link0.stl'
#   sha256='1ad40d9dc4408144c2606cc05ca01d32f243317c92949bec9d18d06fcc8a94e5'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/PA-10/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/PA-10/link3.stl'
#   sha256='fe5fc7460ab44a4c9904a5682afa77462442e72fcccc11512311f0b29b54ed54'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/link5.stl'
#   sha256='042a318d8246d8aa018ba23546069a049f82bfdadc76f7ea1ac8cf138c4c1b82'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/link4.stl'
#   sha256='736f266084f7517e7d213cde8699e1839a11ffbb88cc25f54c38a8461223f0d6'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/link1.stl'
#   sha256='70510f27d5643b7f4889788389976359f717a8133d152426c6e5b2c5759823f2'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/link2.stl'
#   sha256='0abaa10f71a53c97e71e33f5aa2bcb54db4e5636b32da4c5d08404cf7ea31b30'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/link6.stl'
#   sha256='1780c07a027fb4fb021bace94e52478f3e24346a549ccb156d53403c53dfb0f0'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/._link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/._link6.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/link0.stl'
#   sha256='6ec3aa04f3318d67351ab0684254c1aaa65b4603cda720b438f5d72cf811c342'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv_3sb/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv_3sb/link3.stl'
#   sha256='f604f7ce967bc2106da1a47746a893185da71949594987049d4bc9dd9e4ad3fb'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/link5.stl'
#   sha256='322a9d93ee243e9be5951739b4e4b4ff19d754f3c3bbda444dee86a1cf53aeab'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/link4.stl'
#   sha256='aca518819341e5b1e1347342eff30dbe9db1e6d34ee1039580337d4828eb9b67'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/link1.stl'
#   sha256='afd2389adf1da83853d6723ae9dbee52f4998e75816e846c92f060326cd87f73'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/link2.stl'
#   sha256='43b9f89b8a695117c3a703ca11dcb2b08719496e67cb67d3f2c3958bd52e8e3f'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/link6.stl'
#   sha256='5ca63478ef8f73e381812ed6bc3762193ea388e54e1ca5d360ddfe32a7f26854'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
# Handling 3D object files:   2%|▏         | 34/1584 [00:00<00:04, 326.45it/s]
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/._link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/._link6.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/link0.stl'
#   sha256='a8c2bca3c4fcd7a1662e2fc3e8256cdecb94d65e3e7d66943daefd85e91ef3f9'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-7f/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-7f/link3.stl'
#   sha256='fd6436bf24973be70887cee5399c9f4c993173c4db29bb06a8316d90a0043901'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/link5.stl'
#   sha256='7828b02e00d077e8f9325cb1ed57c76a8d7fdec76369b5e9b57bcdd5c878bbca'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/link4.stl'
#   sha256='705c2e13c71995d0cd5af6477b5ce80368f2b589fe2d27bdf8c8dc72cd65680d'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/link1.stl'
#   sha256='ef3e645262d49a4403f69bb3e27e26f1833f2257f8f3241468d60d909ee6a6db'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/link2.stl'
#   sha256='2cd5e455d2b3fd8e88f2c315df059056a6f3175ce3aa6f64bc47496452a5c3a7'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/link6.stl'
#   sha256='5ca63478ef8f73e381812ed6bc3762193ea388e54e1ca5d360ddfe32a7f26854'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/._link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/._link6.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/link0.stl'
#   sha256='a8c2bca3c4fcd7a1662e2fc3e8256cdecb94d65e3e7d66943daefd85e91ef3f9'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/MITSUBISHI/rv-6s/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/MITSUBISHI/rv-6s/link3.stl'
#   sha256='8bb8dfa43260aa9a22d4b54e1558b6dad92fac6112ce8cfea06b261846287fa5'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/link5.stl'
#   sha256='b873f0ff5d1a910827629005346b6ef616ce21c3cbcaf0144fcd7490b124995d'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/link4.stl'
#   sha256='237308698ac3e3add3e856102c7f8006724763c7bfa3f6f596431c8c6ac724e8'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/link1.stl'
#   sha256='42f020a2509a24f3c514ae2dfcc944f759d20d9510a31d1f14e7a9d7d3ad9843'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/link2.stl'
#   sha256='5294b92d3970ffb54c8978f850b3c8d2a599256a23f6510f10f4ed18075685a3'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/link0.stl'
#   sha256='1235b9d0bcd1ec3b04b217e6bff27ad721a0f021c81a71ad22f246913f5bc8b0'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
# Handling 3D object files:   4%|▍         | 67/1584 [00:00<00:05, 253.06it/s]
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR120_R3200_PA/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR120_R3200_PA/link3.stl'
#   sha256='56d7bfead7c2979bca422f6f44ffe775addaffc83e17131bd3c817b6a99b49d4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/link5.stl'
#   sha256='287fd817c3224f04c9710294bb4fb76e56b3a75f61aa8cf13b22758ffe52527a'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/link4.stl'
#   sha256='5caa20668dacf8ff18b852894cbe36e0228d9cc158899c582924ace33687bbd9'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/link1.stl'
#   sha256='366c46dba07ee3fad1f0215d9b68a4a58d1b32c237c0ce3363ca53e8659bfd5c'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/link2.stl'
#   sha256='67bde8ff02315a473303db9d9f1586ceb1cda85aa9abece726a32d1c09c22ca6'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/link6.stl'
#   sha256='bde2c83275dd9f778f112e8fbf9f41352c3f34e6096436bf891fe903f5b74d66'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/._link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/._link6.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/link0.stl'
#   sha256='4402dede9078e1cc78db821d1b766c5dd7e88ac70fb6941626f09e686bf10b07'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR5_arc/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR5_arc/link3.stl'
#   sha256='ba6faf53969a17a7d3180a02c3a775cf269ff6d0052269959494e541f6a44b7b'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/link5.stl'
#   sha256='9c8728d122d787e33eb5e9a899f910fec3341266e9604feaf328f65644442e67'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/link4.stl'
#   sha256='a7fd8b3c38095bf77998ba35ac0d80a90c9cc24d10dc2f42e47886c490a57961'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/link1.stl'
#   sha256='77873a0de94b26df9fd36d00969c8ae59df909c099d8bc5d4ae91e400ec92ef8'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/link2.stl'
#   sha256='4c71e0d348e081b3adcf0fd420c6c0e2e9d8e9486907b3e457d4c889b2bed8e0'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/link6.stl'
#   sha256='688463ff04a6b0cf33d2b2aca1aebbbf94004e9fb8d69e5ab359e27696b25b29'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/._link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/._link6.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/link0.stl'
#   sha256='6181368bcf769c4d46bc07ae602b76d176831904cec6777c395a0b98d96cac3c'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
# Handling 3D object files:   6%|▌         | 94/1584 [00:00<00:06, 218.31it/s]
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR3_R540/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR3_R540/link3.stl'
#   sha256='536d5a7df72ec2ddd91a41b60f3cc17b2ff936acabc9d3d3e7f8329040890069'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/link5.stl'
#   sha256='cea9a425e8bab0e53a0a406ead73136fb4c80a523f8d7bdbf9c3edccfe6ea85c'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/link4.stl'
#   sha256='4cb31cb7e229b049890dac19d79940020359b9613ca6c1671cba7c01df1ad59e'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/link1.stl'
#   sha256='b94a0e1bdaf5a6b3f1394931f38a1e83512f44f0e67fa6d8f1d1420a89c57e84'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/link2.stl'
#   sha256='c7cca7b800ed26804191af002aa9bc74b02b29d0bdafc0ff9ebdd3d477ffbf7c'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/link6.stl'
#   sha256='bf475ce1f4e07bd379c0b968b1f12c72538e3149a781f30685cfc38e81c8f99b'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/._link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/._link6.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/link0.stl'
#   sha256='15b0ff5c720a95d9231857a3d47c5e57a1d7365fc074a160938dc580d29d39ac'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/KUKA/KR30_jet/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/KUKA/KR30_jet/link3.stl'
# ...
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
# Handling 3D object files:  98%|█████████▊| 1547/1584 [00:07<00:00, 199.15it/s]
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/Prosix_C4_A60/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/Prosix_C4_A60/link0.stl'
#   sha256='b791d6ad0cbfe6c70749c7d8b39fde398fb93a808469b12483bce8d4c227bebc'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/Prosix_C4_A60/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/Prosix_C4_A60/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/Prosix_C4_A60/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/Prosix_C4_A60/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/Prosix_C4_A60/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/Prosix_C4_A60/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/Prosix_C4_A60/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/Prosix_C4_A60/link3.stl'
#   sha256='ca31d2d9b1e791bcbd83926753ae78efb29fc7b5ba524311e45cf8d8d4fa6a0b'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/link5.stl'
#   sha256='e99efd269c03d56fcaa62dbdd2f18140c4308a288f4cf83125f39f12e66bcc85'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/link4.stl'
#   sha256='f61fe8c41a32884355fcb7fc2365246fc0d7ef6339b33d3fbb4f7cdcdbb96ab7'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/link1.stl'
#   sha256='09fbca0dab5633a365f1729590cc7de0e482334ba4208f32529a2bcb1603dc09'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/link2.stl'
#   sha256='13b97d5572bca331bcf34f06d69cd902ffc204334b6cc70289fe4a1ca8e137ae'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/link6.stl'
#   sha256='90a6b50f74fc952c68f2f70ca20d23e4232cc1047866f129c1b4b123c63d6169'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/._link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/._link6.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/link0.stl'
#   sha256='de323839024d6d2bf282eef4cff2c2fc46bb19d4f3593d7ae6ab03abdec20beb'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8L/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8L/link3.stl'
#   sha256='7de17530a13921ea1ed303620bf195c7d4d5623ecb18fdfc768f155a311429a3'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/link5.stl'
#   sha256='2071ff5ad84e5783f805c81228fb9a38dea809aff3578e350e5f4adfe2c2fe09'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/link4.stl'
#   sha256='40e60588f1b3fb4c7bbd46b3b2bc87a6d31c98f033c037aae7d8294a23bbad1b'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/link1.stl'
#   sha256='bdb9b95721e7925582b797e7d5cb50b5e1dfaca9c51e45324e9e5cbcb2c9ea8b'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/._link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/._link2.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
# Handling 3D object files:  99%|█████████▉| 1570/1584 [00:07<00:00, 205.71it/s]
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/link2.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/link2.stl'
#   sha256='5e817bd7dd66a846f714bbff90a54357273e90cbadc78cd0a3616999e8c65683'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/link6.stl'
#   sha256='1e0b6bb896fb43a0a5cc3ed3c898a4bdfde78aec64a951e170dd0da9bed465ae'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/._link6.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/._link6.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/._link1.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/._link1.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/._link5.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/._link5.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/link0.stl'
#   sha256='73a6f75a30bae3f03323c1e783625c24bfa48d7db1c0bc171d199b191fe20cf5'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/._link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/._link3.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/._link4.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/._link4.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/robots/EPSON/C8/link3.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/robots/EPSON/C8/link3.stl'
#   sha256='579c2c3b3cb782bd76ab77a88d9bc27389b3ca22376682b656f02552d85baeb2'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/tools/draw_demos/._cil.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/tools/draw_demos/._cil.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/tools/draw_demos/cil.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/tools/draw_demos/cil.stl'
#   sha256='cf24d19f393a5f2bc698b3e50ac168b3c47b2533a6cc689fcf9cb480a47cd849'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/tools/draw_demos/link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/tools/draw_demos/link0.stl'
#   sha256='2788f53991c665ab6110c8b067f3b01df0b6b31015e04ca291163b9baee700e1'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
#
#
#
#
#
#
# ---HANDLE_NEW_OBJECT CALLED---
#    local_path='/tmp/tmporp8d5bj/SCO_planning/tools/draw_demos/._link0.stl'
#   file_identifier='https://github.com/jcarballeira/SCO_planning/blob/930dbf46cd01dc1996cf7969b96f2fb764a233be/tools/draw_demos/._link0.stl'
#   sha256='1f5dbd3f608130c763e46f69cdd8926f2ad4f9438ea7fa0adc0812998cbd84c4'
#   metadata={'github_organization': 'jcarballeira', 'github_repo': 'SCO_planning'}
# Handling 3D object files: 100%|██████████| 1584/1584 [00:07<00:00, 214.15it/s]
# Downloading repositories: 100%|██████████| 1/1 [00:30<00:00, 30.91s/it]
# {'https://3d-api.si.edu/content/document/3d_package:eb2cdb65-0c0d-43ee-b0e4-a735d0795d07/USNM176228_talus_right_-300-150k-2048-medium.glb': '/home/lzy/.objaverse/smithsonian/objects/31421480-4f0c-550f-afd1-a4b791dc59a2.glb',
#  'https://sketchfab.com/3d-models/c5db69692262401c8fcce0567135894e': '/home/lzy/.objaverse/hf-objaverse-v1/glbs/000-060/c5db69692262401c8fcce0567135894e.glb'}

# %% [markdown]
# Notice that `handle_new_object` gets called a bunch of times!
#
# For even more objects, one may want to experiment with using the latest Git commits, instead of the ones used with Objaverse-XL, as it'll likely lead to more objects being available. Here, `handle_new_object` would be quite a useful callback!

# %% [markdown]
# ## Next Steps
#
# Take a look at the [Blender rendering code](https://github.com/allenai/objaverse-xl/tree/main/scripts/rendering) for rendering Objaverse-XL objects in Blender and extracting metadata from the objects!
